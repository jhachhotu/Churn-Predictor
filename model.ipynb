# %%
# %pip install tensorflow==2.15.0
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# Collecting tensorflow==2.15.0
#   Using cached tensorflow-2.15.0-cp310-cp310-win_amd64.whl (2.1 kB)
# Collecting tensorflow-intel==2.15.0
#   Using cached tensorflow_intel-2.15.0-cp310-cp310-win_amd64.whl (300.9 MB)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\abhis\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.80.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.0)
# Collecting tensorflow-estimator<2.16,>=2.15.0
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.7.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (25.12.19)
# Collecting numpy<2.0.0,>=1.23.5
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\abhis\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.17.0)
# Requirement already satisfied: setuptools in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (57.4.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0
#   Using cached ml_dtypes-0.2.0-cp310-cp310-win_amd64.whl (938 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.4.0)
# Collecting tensorboard<2.16,>=2.15
#   Using cached tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.14.0)
# Collecting wrapt<1.15,>=1.11.0
#   Using cached wrapt-1.14.2-cp310-cp310-win_amd64.whl (35 kB)
# Requirement already satisfied: packaging in c:\users\abhis\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (26.1)
# Collecting keras<2.16,>=2.15.0
#   Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.25.9)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.46.3)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.1.8)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.33.1)
# Collecting markdown>=2.6.8
#   Using cached markdown-3.10.2-py3-none-any.whl (108 kB)
# Collecting google-auth-oauthlib<2,>=0.5
#   Using cached google_auth_oauthlib-1.3.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.49.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (46.0.7)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.6.3)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2026.2.25)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3.1)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.0.3)
# Installing collected packages: numpy, markdown, google-auth-oauthlib, wrapt, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, ml-dtypes, keras, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\abhis\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\~umpy.libs\\libscipy_openblas64_-13e2df515630b4a41f92893938845698.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhis\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\Users\abhis\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
np.random.seed(42)
tf.random.set_seed(42)


# ── 2. LOAD DATA ─────────────────────────────────────────────
df = pd.read_csv("Artificial_Neural_Network_Case_Study_data.csv")

print("Shape:", df.shape)
print(df.head())
print("\nChurn Rate: {:.2f}%".format(df['Exited'].mean() * 100))
# Out:
# Shape: (10000, 14)
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
#
# Churn Rate: 20.37%

# %%
# ── 3. PREPROCESSING ─────────────────────────────────────────
# Drop irrelevant columns
df.drop(columns=['RowNumber', 'CustomerId', 'Surname'], inplace=True)

# Encode Gender
df['Gender'] = LabelEncoder().fit_transform(df['Gender'])  # Female=0, Male=1

# One-Hot Encode Geography
df = pd.get_dummies(df, columns=['Geography'], drop_first=True)

# Features & Target
X = df.drop('Exited', axis=1)
feature_columns = X.columns.tolist()
y = df['Exited'].values

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X.values, y, test_size=0.2, random_state=42, stratify=y
)

# Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

print("\nX_train:", X_train.shape, "| X_test:", X_test.shape)
# Out:
# X_train: (8000, 11) | X_test: (2000, 11)

# %%
# ── 4. BUILD ANN ─────────────────────────────────────────────
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.3),

    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),

    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\abhis\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,265 (12.75 KB)
#  Trainable params: 3,073 (12.00 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
# ── 5. TRAIN ──────────────────────────────────────────────────
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    class_weight={0: 1, 1: 2},   # handle class imbalance
    verbose=1
)
# Out:
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6756 - loss: 0.8055 - val_accuracy: 0.8300 - val_loss: 0.4177
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7663 - loss: 0.6783 - val_accuracy: 0.8400 - val_loss: 0.3900
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7922 - loss: 0.6359 - val_accuracy: 0.8438 - val_loss: 0.3795
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8048 - loss: 0.6024 - val_accuracy: 0.8394 - val_loss: 0.3703
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8077 - loss: 0.5940 - val_accuracy: 0.8400 - val_loss: 0.3718
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8075 - loss: 0.5897 - val_accuracy: 0.8419 - val_loss: 0.3664
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8144 - loss: 0.5741 - val_accuracy: 0.8450 - val_loss: 0.3662
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8181 - loss: 0.5657 - val_accuracy: 0.8469 - val_loss: 0.3610
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8230 - loss: 0.5665 - val_accuracy: 0.8475 - val_loss: 0.3612
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8202 - loss: 0.5591 - val_accuracy: 0.8494 - val_loss: 0.3598
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8241 - loss: 0.5608 - val_accuracy: 0.8487 - val_loss: 0.3576
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8261 - loss: 0.5425 - val_accuracy: 0.8519 - val_loss: 0.3542
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8280 - loss: 0.5483 - val_accuracy: 0.8525 - val_loss: 0.3565
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8308 - loss: 0.5370 - val_accuracy: 0.8569 - val_loss: 0.3517
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8302 - loss: 0.5422 - val_accuracy: 0.8500 - val_loss: 0.3556
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8334 - loss: 0.5319 - val_accuracy: 0.8556 - val_loss: 0.3533
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8289 - loss: 0.5363 - val_accuracy: 0.8525 - val_loss: 0.3527
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8291 - loss: 0.5333 - val_accuracy: 0.8525 - val_loss: 0.3528
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8331 - loss: 0.5305 - val_accuracy: 0.8562 - val_loss: 0.3500
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8398 - loss: 0.5257 - val_accuracy: 0.8556 - val_loss: 0.3467
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8344 - loss: 0.5273 - val_accuracy: 0.8512 - val_loss: 0.3527
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8345 - loss: 0.5210 - val_accuracy: 0.8519 - val_loss: 0.3499
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8353 - loss: 0.5241 - val_accuracy: 0.8506 - val_loss: 0.3488
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8297 - loss: 0.5261 - val_accuracy: 0.8525 - val_loss: 0.3537
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8406 - loss: 0.5262 - val_accuracy: 0.8506 - val_loss: 0.3527
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8334 - loss: 0.5240 - val_accuracy: 0.8537 - val_loss: 0.3513
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8356 - loss: 0.5222 - val_accuracy: 0.8531 - val_loss: 0.3500
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8388 - loss: 0.5194 - val_accuracy: 0.8512 - val_loss: 0.3462
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8375 - loss: 0.5204 - val_accuracy: 0.8531 - val_loss: 0.3493
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8394 - loss: 0.5091 - val_accuracy: 0.8531 - val_loss: 0.3454
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8411 - loss: 0.5164 - val_accuracy: 0.8531 - val_loss: 0.3504
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8373 - loss: 0.5191 - val_accuracy: 0.8531 - val_loss: 0.3493
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8422 - loss: 0.5090 - val_accuracy: 0.8512 - val_loss: 0.3494
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8377 - loss: 0.5179 - val_accuracy: 0.8512 - val_loss: 0.3469
# Epoch 35/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8386 - loss: 0.5143 - val_accuracy: 0.8531 - val_loss: 0.3458
# Epoch 36/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8397 - loss: 0.5094 - val_accuracy: 0.8519 - val_loss: 0.3495
# Epoch 37/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8419 - loss: 0.5084 - val_accuracy: 0.8550 - val_loss: 0.3477
# Epoch 38/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8341 - loss: 0.5204 - val_accuracy: 0.8544 - val_loss: 0.3491
# Epoch 39/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8405 - loss: 0.5074 - val_accuracy: 0.8562 - val_loss: 0.3467
# Epoch 40/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8386 - loss: 0.5098 - val_accuracy: 0.8512 - val_loss: 0.3492

# %%
# ── 6. EVALUATE ───────────────────────────────────────────────
y_pred  = (model.predict(X_test) >= 0.5).astype(int).ravel()
y_prob  = model.predict(X_test).ravel()

_, acc  = model.evaluate(X_test, y_test, verbose=0)
auc     = roc_auc_score(y_test, y_prob)

print(f"\nTest Accuracy : {acc*100:.2f}%")
print(f"Test AUC-ROC  : {auc:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Retained', 'Churned']))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
#
# Test Accuracy : 84.65%
# Test AUC-ROC  : 0.8604
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Retained       0.90      0.90      0.90      1593
#      Churned       0.62      0.62      0.62       407
#
#     accuracy                           0.85      2000
#    macro avg       0.76      0.76      0.76      2000
# weighted avg       0.85      0.85      0.85      2000

# %%
# ── 7. PLOTS ──────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

# Training curves
axes[0].plot(history.history['accuracy'],     label='Train')
axes[0].plot(history.history['val_accuracy'], label='Val')
axes[0].set_title('Accuracy'); axes[0].legend()

axes[1].plot(history.history['loss'],     label='Train')
axes[1].plot(history.history['val_loss'], label='Val')
axes[1].set_title('Loss'); axes[1].legend()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[2],
            xticklabels=['Retained', 'Churned'],
            yticklabels=['Retained', 'Churned'])
axes[2].set_title('Confusion Matrix')
axes[2].set_xlabel('Predicted'); axes[2].set_ylabel('Actual')

plt.tight_layout()
plt.savefig('results.png', dpi=150)
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_prob)
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f'AUC = {auc:.4f}', color='steelblue', lw=2)
plt.plot([0,1],[0,1],'k--')
plt.title('ROC Curve'); plt.xlabel('FPR'); plt.ylabel('TPR')
plt.legend(); plt.tight_layout()
plt.savefig('roc_curve.png', dpi=150)
plt.show()

# %%
# ── 8. PREDICT NEW CUSTOMER ───────────────────────────────────
# Example: CreditScore, Gender(0=F,1=M), Age, Tenure, Balance,
#          NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary,
#          Geography_Germany, Geography_Spain
new_customer = scaler.transform([[600, 1, 40, 3, 60000, 2, 1, 1, 80000, 0, 0]])
prob = model.predict(new_customer)[0][0]
stay_prob = 1 - prob
print(f"\nNew Customer Churn Probability: {prob*100:.2f}%")
print(f"New Customer Stay Probability: {stay_prob*100:.2f}%")
print("Prediction:", "WILL CHURN" if prob >= 0.5 else "WILL STAY")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# New Customer Churn Probability: 5.75%
# New Customer Stay Probability: 94.25%
# Prediction: WILL STAY

# %%
from pathlib import Path
import json
import pickle

# ── 9. SAVE ARTIFACTS ─────────────────────────────────────────
artifacts_dir = Path('artifacts')
artifacts_dir.mkdir(exist_ok=True)

model.save(artifacts_dir / 'churn_ann_model.keras')

with open(artifacts_dir / 'scaler.pkl', 'wb') as file_handle:
    pickle.dump(scaler, file_handle)

with open(artifacts_dir / 'feature_columns.json', 'w', encoding='utf-8') as file_handle:
    json.dump(feature_columns, file_handle, indent=2)

print('Saved model to artifacts/churn_ann_model.keras')
print('Saved scaler to artifacts/scaler.pkl')
print('Saved feature columns to artifacts/feature_columns.json')
# Out:
# Saved model to artifacts/churn_ann_model.keras
# Saved scaler to artifacts/scaler.pkl
# Saved feature columns to artifacts/feature_columns.json
